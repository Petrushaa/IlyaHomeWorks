# %%
N = int(input("Введи N"))
print('Ты ввел:', N)

def fib_regular(N:int) -> int:
    if N <= 1:
        return N
    return fib_regular(N-1) + fib_regular(N-2)

print('N-ое число в Фибоначи:', fib_regular(N))
# Out:
# Ты ввел: 19
# N-ое число в Фибоначи: 4181
