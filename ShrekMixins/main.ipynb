# %%
#Миксины
class MixinSpeakable:  # Возможность говорить
    def speak(self):
        print(f"{self.name} говорит")
    
class MixinAnimated: #анимированность
    is_animated = True

class MixinFunny: #возможность шутить
    def make_laugh(self):
        print(f"{self.name} пошутил")

class MixinActionable: #возможность выполнять действия
    def perform_action(self):
        print(f"{self.name} cделал аперкот")

class MixinCollectible:#возможность быть коллекционным
    is_collectible = True

class MixinPoseable: #возможность принимать позы
    def pose(self):
        print(f"{self.name} поменял позу")

class MixinCostumeWearable: #возможность носить костюмы
    costume:str = "Костюм"

#Базовые классы
class BaseCharacter(MixinSpeakable, MixinAnimated, MixinFunny):
    def __init__(self, name):
        self.name = name

class BaseInAnctionCharacter(BaseCharacter, MixinActionable): #персонажи в действии (наследуется от BaseCharacter)
    ...

class BaseFunkoPop(BaseCharacter, MixinCollectible): #фигурки Funko Pop (наследуется от BaseCharacter)
    def display(self):
        print("Я пластиковая поебота")

class BaseHuman:
    is_human = True

class BaseCosplayer(BaseCharacter, BaseHuman,MixinPoseable, MixinCostumeWearable):
    def __init__(self):
        super().__init__()  # Вызываем конструктор BaseCharacter
        self.costume = "Костюм для косплея"  # Инициализируем костюм



class Shrek(BaseCharacter):
    def __init__(self):
        super().__init__("Шрек")

class PussInBoots(BaseCharacter):
    def __init__(self):
        super().__init__("Кот в сапогах")

class Donkey(BaseCharacter):
    def __init__(self):
        super().__init__("Осел")

class JackHorner(BaseCharacter):
    def __init__(self):
        super().__init__("Джек Хорни")


#Нижние сословия

#In Actions
class ShrekInAction(BaseInAnctionCharacter, Shrek):
    def __init__(self):
        super().__init__()

class PussInBootsInAction(BaseInAnctionCharacter, PussInBoots):
    def __init__(self):
        super().__init__()

class DonkeyInAction(BaseInAnctionCharacter, Donkey):
    def __init__(self):
        super().__init__()

class JackHornerInAction(BaseInAnctionCharacter, JackHorner):
    def __init__(self):
        super().__init__()

#FunkoPops
class ShrekFunkoPop(BaseFunkoPop, Shrek):
    def __init__(self):
        super().__init__()

class PussInBootsFunkoPop(BaseFunkoPop,PussInBoots):
    def __init__(self):
        super().__init__()

class DonkeyFunkoPop(BaseFunkoPop, Donkey):
    def __init__(self):
        super().__init__()

class JackHornerFunkoPop(BaseFunkoPop, JackHorner):
    def __init__(self):
        super().__init__()

#Cosplayers
class ShrekCosplayer(BaseCosplayer, Shrek):
    def __init__(self):
        super().__init__()

class PussInBootsCosplayer(BaseCosplayer, PussInBoots):
    def __init__(self):
        super().__init__()

class DonkeyCosplayer(BaseCosplayer,Donkey):
    def __init__(self):
        super().__init__()

class JackHornerCosplayer(BaseCosplayer, JackHorner):
    def __init__(self,):
        super().__init__()


Shrek1 = ShrekInAction()
Shrek1.speak()
print(Shrek1.is_animated)
Shrek1.make_laugh()
print(Shrek1.name)

Donkey1 = DonkeyFunkoPop()
Donkey1.speak()
print(f"{Donkey1.is_collectible} коллекционный")

JackHorner1 = JackHornerCosplayer()

JackHorner1.pose()
print(JackHorner1.costume)
# Out:
# Шрек говорит
# True
# Шрек пошутил
# Шрек
# Осел говорит
# True коллекционный
# Джек Хорни поменял позу
# Костюм для косплея
